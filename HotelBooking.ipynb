# %% [markdown]
# <div style="
#     background-color: #3498db;
#     color: white;
#     border: 5px solid #2980b9;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 4em;
#     font-family: Arial, sans-serif;
#     font-weight: bold;
#     padding: 30px;
# ">
#     شیکردنەوەی داتای تۆمارکردنی هۆتێل<br> (Hotel Booking Data Analysis)

# %%
import pandas as pd
import numpy as np

# %%
mydata = pd.read_csv('hotel_booking.csv')

# %%
mydata.tail(5)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 69994  City Hotel            1        130               2017
# 69995  City Hotel            1        130               2017
# 69996  City Hotel            1        169               2017
# 69997  City Hotel            1         29               2017
# 69998  City Hotel            1        110               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 69994               June                        23                          8
# 69995               June                        23                          8
# 69996               June                        23                          8
# 69997               June                        23                          8
# 69998               June                        23                          8
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 69994                        0                     3       2  ...
# 69995                        0                     3       2  ...
# 69996                        0                     3       2  ...
# 69997                        0                     3       2  ...
# 69998                        0                     3       2  ...
#
#        customer_type     adr required_car_parking_spaces  \
# 69994      Transient  162.00                           0
# 69995      Transient  149.33                           0
# 69996      Transient  170.00                           0
# 69997      Transient  214.67                           0
# 69998      Transient  153.00                           0
#
#       total_of_special_requests reservation_status reservation_status_date  \
# 69994                         0           Canceled              2017-01-29
# 69995                         0           Canceled              2017-05-05
# 69996                         0           Canceled              2016-12-21
# 69997                         1           Canceled              2017-05-10
# 69998                         0           Canceled              2017-02-28
#
#                    name                     email  phone-number  \
# 69994        Troy James        TJames@xfinity.com  115-702-5154
# 69995       Roger Smith   Smith.Roger42@gmail.com  788-113-8497
# 69996      Shawn Valdez      Shawn.Valdez@att.com  248-845-7180
# 69997  Kathleen Jackson      Kathleen_J28@aol.com  681-445-8114
# 69998     Anthony Mason  Mason_Anthony47@zoho.com  230-901-9291
#
#             credit_card
# 69994  ************1590
# 69995  ************6202
# 69996  ************5436
# 69997  ************9923
# 69998  ************3666
#
# [5 rows x 36 columns]

# %%
# Load the Hotels Dataset
mydata = pd.read_csv('hotel_booking.csv')

# %%
# mydata.head()
mydata.columns
#mydata.info()
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
mydata.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  69999.000000  69999.000000       69999.000000
# mean       0.504550    106.397549        2016.091987
# std        0.499983    107.241674           0.709101
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     21.000000        2016.000000
# 50%        1.000000     74.000000        2016.000000
# 75%        1.000000    163.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              69999.000000               69999.000000
# mean                  27.117316                  15.700510
# std                   13.931516                   8.838679
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   39.000000                  23.000000
# max                   53.000000                  31.000000
#
#        stays_in_weekend_nights  stays_in_week_nights        adults  \
# count             69999.000000          69999.000000  69999.000000
# mean                  1.018515              2.769282      1.865827
# std                   1.073381              2.151176      0.611889
# min                   0.000000              0.000000      0.000000
# 25%                   0.000000              1.000000      2.000000
# 50%                   1.000000              2.000000      2.000000
# 75%                   2.000000              4.000000      2.000000
# max                  19.000000             50.000000     55.000000
#
#            children        babies  is_repeated_guest  previous_cancellations  \
# count  69995.000000  69999.000000       69999.000000            69999.000000
# mean       0.108736      0.009214           0.025400                0.058215
# std        0.411659      0.103308           0.157339                1.011264
# min        0.000000      0.000000           0.000000                0.000000
# 25%        0.000000      0.000000           0.000000                0.000000
# 50%        0.000000      0.000000           0.000000                0.000000
# 75%        0.000000      0.000000           0.000000                0.000000
# max       10.000000     10.000000           1.000000               26.000000
#
#        previous_bookings_not_canceled  booking_changes         agent  \
# count                    69999.000000     69999.000000  59506.000000
# mean                         0.083815         0.217203    129.015276
# std                          0.761431         0.659984    120.613421
# min                          0.000000         0.000000      1.000000
# 25%                          0.000000         0.000000      9.000000
# 50%                          0.000000         0.000000     96.000000
# 75%                          0.000000         0.000000    240.000000
# max                         30.000000        20.000000    535.000000
#
#            company  days_in_waiting_list           adr  \
# count  3784.000000          69999.000000  69999.000000
# mean    222.584831              3.185874     98.025760
# std     130.736735             21.710505     55.815161
# min       6.000000              0.000000     -6.380000
# 25%     110.000000              0.000000     62.000000
# 50%     223.000000              0.000000     88.400000
# 75%     307.000000              0.000000    121.500000
# max     543.000000            391.000000   5400.000000
#
#        required_car_parking_spaces  total_of_special_requests
# count                 69999.000000               69999.000000
# mean                      0.081344                   0.489678
# std                       0.277720                   0.758169
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       0.000000                   0.000000
# 75%                       0.000000                   1.000000
# max                       8.000000                   5.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="hotel", y="stays_in_week_nights", data=mydata)
# Out:
# <Axes: xlabel='hotel', ylabel='stays_in_week_nights'>

# %%
pd.crosstab(mydata['country'],mydata['meal'] )
# Out:
# meal      BB  FB  HB  SC  Undefined
# country
# AGO      174   0   1  60          0
# ALB        4   0   0   1          0
# AND        4   0   1   2          0
# ARE       38   0   1   6          0
# ARG       80   0   6  10          0
# ...      ...  ..  ..  ..        ...
# VGB        0   0   0   1          0
# VNM        3   0   1   0          0
# ZAF       27   0   1  13          0
# ZMB        1   0   0   1          0
# ZWE        1   0   1   0          0
#
# [149 rows x 5 columns]

# %%
pd.crosstab(mydata['hotel'],mydata['reserved_room_type'] )
# Out:
# reserved_room_type      A    B    C     D     E     F     G    H  L  P
# hotel
# City Hotel          24641  487    4  3653   386   670    90    0  0  8
# Resort Hotel        23399    3  918  7433  4982  1106  1610  601  6  2

# %%
sns.countplot(x="hotel", hue="distribution_channel", data=mydata)
# Out:
# <Axes: xlabel='hotel', ylabel='stays_in_week_nights'>

# %%
pd.pivot_table(mydata, index=['country', 'hotel'],
                     columns=[ 'meal'], aggfunc=len)
# Out:
#                         adr                          adults                 \
# meal                     BB  FB   HB    SC Undefined     BB  FB   HB    SC
# country hotel
# AGO     City Hotel    150.0 NaN  1.0  60.0       NaN  150.0 NaN  1.0  60.0
#         Resort Hotel   24.0 NaN  NaN   NaN       NaN   24.0 NaN  NaN   NaN
# ALB     City Hotel      1.0 NaN  NaN   1.0       NaN    1.0 NaN  NaN   1.0
#         Resort Hotel    3.0 NaN  NaN   NaN       NaN    3.0 NaN  NaN   NaN
# AND     City Hotel      NaN NaN  NaN   2.0       NaN    NaN NaN  NaN   2.0
# ...                     ...  ..  ...   ...       ...    ...  ..  ...   ...
# ZAF     City Hotel     11.0 NaN  NaN  12.0       NaN   11.0 NaN  NaN  12.0
#         Resort Hotel   16.0 NaN  1.0   1.0       NaN   16.0 NaN  1.0   1.0
# ZMB     City Hotel      NaN NaN  NaN   1.0       NaN    NaN NaN  NaN   1.0
#         Resort Hotel    1.0 NaN  NaN   NaN       NaN    1.0 NaN  NaN   NaN
# ZWE     Resort Hotel    1.0 NaN  1.0   NaN       NaN    1.0 NaN  1.0   NaN
#
#                                 ... stays_in_weekend_nights                 \
# meal                 Undefined  ...                      BB  FB   HB    SC
# country hotel                   ...
# AGO     City Hotel         NaN  ...                   150.0 NaN  1.0  60.0
#         Resort Hotel       NaN  ...                    24.0 NaN  NaN   NaN
# ALB     City Hotel         NaN  ...                     1.0 NaN  NaN   1.0
#         Resort Hotel       NaN  ...                     3.0 NaN  NaN   NaN
# AND     City Hotel         NaN  ...                     NaN NaN  NaN   2.0
# ...                        ...  ...                     ...  ..  ...   ...
# ZAF     City Hotel         NaN  ...                    11.0 NaN  NaN  12.0
#         Resort Hotel       NaN  ...                    16.0 NaN  1.0   1.0
# ZMB     City Hotel         NaN  ...                     NaN NaN  NaN   1.0
#         Resort Hotel       NaN  ...                     1.0 NaN  NaN   NaN
# ZWE     Resort Hotel       NaN  ...                     1.0 NaN  1.0   NaN
#
#                                total_of_special_requests                 \
# meal                 Undefined                        BB  FB   HB    SC
# country hotel
# AGO     City Hotel         NaN                     150.0 NaN  1.0  60.0
#         Resort Hotel       NaN                      24.0 NaN  NaN   NaN
# ALB     City Hotel         NaN                       1.0 NaN  NaN   1.0
#         Resort Hotel       NaN                       3.0 NaN  NaN   NaN
# AND     City Hotel         NaN                       NaN NaN  NaN   2.0
# ...                        ...                       ...  ..  ...   ...
# ZAF     City Hotel         NaN                      11.0 NaN  NaN  12.0
#         Resort Hotel       NaN                      16.0 NaN  1.0   1.0
# ZMB     City Hotel         NaN                       NaN NaN  NaN   1.0
#         Resort Hotel       NaN                       1.0 NaN  NaN   NaN
# ZWE     Resort Hotel       NaN                       1.0 NaN  1.0   NaN
#
#
# meal                 Undefined
# country hotel
# AGO     City Hotel         NaN
#         Resort Hotel       NaN
# ALB     City Hotel         NaN
#         Resort Hotel       NaN
# AND     City Hotel         NaN
# ...                        ...
# ZAF     City Hotel         NaN
#         Resort Hotel       NaN
# ZMB     City Hotel         NaN
#         Resort Hotel       NaN
# ZWE     Resort Hotel       NaN
#
# [252 rows x 165 columns]

# %%
pd.pivot_table(mydata,'stays_in_week_nights', index=['country'],
                     columns=[ 'hotel'])
# Out:
# hotel    City Hotel  Resort Hotel
# country
# AGO        7.725118      2.250000
# ALB        2.000000      2.000000
# AND        1.000000      4.000000
# ARE        3.676471      2.727273
# ARG        2.564103      2.368421
# ...             ...           ...
# VGB        2.000000           NaN
# VNM        1.000000      2.000000
# ZAF        2.260870      2.666667
# ZMB        1.000000      4.000000
# ZWE             NaN      2.000000
#
# [149 rows x 2 columns]

# %%
mydata['stays_in_week_nights'].std()
# Out:
# np.float64(2.151176310018397)

# %%
mydata['stays_in_week_nights'].mean()
# Out:
# np.float64(2.7692824183202616)

# %%
sns.displot(mydata['stays_in_week_nights'])

# %%
mydata.hist(by='hotel',column = 'stays_in_weekend_nights')
# Out:
# array([<Axes: title={'center': 'City Hotel'}>,
#        <Axes: title={'center': 'Resort Hotel'}>], dtype=object)

# %%
mydata.hist(by='hotel',column = 'lead_time')
# Out:
# array([<Axes: title={'center': 'City Hotel'}>,
#        <Axes: title={'center': 'Resort Hotel'}>], dtype=object)

# %%
mydata.hist(by='hotel',column = 'adults')
# Out:
# array([<Axes: title={'center': 'City Hotel'}>,
#        <Axes: title={'center': 'Resort Hotel'}>], dtype=object)

# %%
mydata.hist(by='country',column = 'adults', figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'AGO'}>, <Axes: title={'center': 'ALB'}>,
#         <Axes: title={'center': 'AND'}>, <Axes: title={'center': 'ARE'}>,
#         <Axes: title={'center': 'ARG'}>, <Axes: title={'center': 'ARM'}>,
#         <Axes: title={'center': 'AUS'}>, <Axes: title={'center': 'AUT'}>,
#         <Axes: title={'center': 'AZE'}>, <Axes: title={'center': 'BDI'}>,
#         <Axes: title={'center': 'BEL'}>, <Axes: title={'center': 'BEN'}>],
#        [<Axes: title={'center': 'BGD'}>, <Axes: title={'center': 'BGR'}>,
#         <Axes: title={'center': 'BHR'}>, <Axes: title={'center': 'BHS'}>,
#         <Axes: title={'center': 'BIH'}>, <Axes: title={'center': 'BLR'}>,
#         <Axes: title={'center': 'BRA'}>, <Axes: title={'center': 'BWA'}>,
#         <Axes: title={'center': 'CAF'}>, <Axes: title={'center': 'CHE'}>,
#         <Axes: title={'center': 'CHL'}>, <Axes: title={'center': 'CHN'}>],
#        [<Axes: title={'center': 'CIV'}>, <Axes: title={'center': 'CMR'}>,
#         <Axes: title={'center': 'CN'}>, <Axes: title={'center': 'COL'}>,
#         <Axes: title={'center': 'COM'}>, <Axes: title={'center': 'CPV'}>,
#         <Axes: title={'center': 'CRI'}>, <Axes: title={'center': 'CUB'}>,
#         <Axes: title={'center': 'CYM'}>, <Axes: title={'center': 'CYP'}>,
#         <Axes: title={'center': 'CZE'}>, <Axes: title={'center': 'DEU'}>],
#        [<Axes: title={'center': 'DJI'}>, <Axes: title={'center': 'DNK'}>,
#         <Axes: title={'center': 'DOM'}>, <Axes: title={'center': 'DZA'}>,
#         <Axes: title={'center': 'ECU'}>, <Axes: title={'center': 'EGY'}>,
#         <Axes: title={'center': 'ESP'}>, <Axes: title={'center': 'EST'}>,
#         <Axes: title={'center': 'ETH'}>, <Axes: title={'center': 'FIN'}>,
#         <Axes: title={'center': 'FJI'}>, <Axes: title={'center': 'FRA'}>],
#        [<Axes: title={'center': 'GAB'}>, <Axes: title={'center': 'GBR'}>,
#         <Axes: title={'center': 'GEO'}>, <Axes: title={'center': 'GGY'}>,
#         <Axes: title={'center': 'GHA'}>, <Axes: title={'center': 'GIB'}>,
#         <Axes: title={'center': 'GLP'}>, <Axes: title={'center': 'GNB'}>,
#         <Axes: title={'center': 'GRC'}>, <Axes: title={'center': 'HKG'}>,
#         <Axes: title={'center': 'HND'}>, <Axes: title={'center': 'HRV'}>],
#        [<Axes: title={'center': 'HUN'}>, <Axes: title={'center': 'IDN'}>,
#         <Axes: title={'center': 'IMN'}>, <Axes: title={'center': 'IND'}>,
#         <Axes: title={'center': 'IRL'}>, <Axes: title={'center': 'IRN'}>,
#         <Axes: title={'center': 'IRQ'}>, <Axes: title={'center': 'ISL'}>,
#         <Axes: title={'center': 'ISR'}>, <Axes: title={'center': 'ITA'}>,
#         <Axes: title={'center': 'JAM'}>, <Axes: title={'center': 'JEY'}>],
#        [<Axes: title={'center': 'JOR'}>, <Axes: title={'center': 'JPN'}>,
#         <Axes: title={'center': 'KAZ'}>, <Axes: title={'center': 'KEN'}>,
#         <Axes: title={'center': 'KHM'}>, <Axes: title={'center': 'KNA'}>,
#         <Axes: title={'center': 'KOR'}>, <Axes: title={'center': 'KWT'}>,
#         <Axes: title={'center': 'LBN'}>, <Axes: title={'center': 'LIE'}>,
#         <Axes: title={'center': 'LKA'}>, <Axes: title={'center': 'LTU'}>],
#        [<Axes: title={'center': 'LUX'}>, <Axes: title={'center': 'LVA'}>,
#         <Axes: title={'center': 'MAC'}>, <Axes: title={'center': 'MAR'}>,
#         <Axes: title={'center': 'MCO'}>, <Axes: title={'center': 'MDG'}>,
#         <Axes: title={'center': 'MDV'}>, <Axes: title={'center': 'MEX'}>,
#         <Axes: title={'center': 'MKD'}>, <Axes: title={'center': 'MLT'}>,
#         <Axes: title={'center': 'MNE'}>, <Axes: title={'center': 'MOZ'}>],
#        [<Axes: title={'center': 'MUS'}>, <Axes: title={'center': 'MWI'}>,
#         <Axes: title={'center': 'MYS'}>, <Axes: title={'center': 'NGA'}>,
#         <Axes: title={'center': 'NIC'}>, <Axes: title={'center': 'NLD'}>,
#         <Axes: title={'center': 'NOR'}>, <Axes: title={'center': 'NPL'}>,
#         <Axes: title={'center': 'NZL'}>, <Axes: title={'center': 'OMN'}>,
#         <Axes: title={'center': 'PAK'}>, <Axes: title={'center': 'PER'}>],
#        [<Axes: title={'center': 'PHL'}>, <Axes: title={'center': 'PLW'}>,
#         <Axes: title={'center': 'POL'}>, <Axes: title={'center': 'PRI'}>,
#         <Axes: title={'center': 'PRT'}>, <Axes: title={'center': 'QAT'}>,
#         <Axes: title={'center': 'ROU'}>, <Axes: title={'center': 'RUS'}>,
#         <Axes: title={'center': 'RWA'}>, <Axes: title={'center': 'SAU'}>,
#         <Axes: title={'center': 'SEN'}>, <Axes: title={'center': 'SGP'}>],
#        [<Axes: title={'center': 'SMR'}>, <Axes: title={'center': 'SRB'}>,
#         <Axes: title={'center': 'STP'}>, <Axes: title={'center': 'SUR'}>,
#         <Axes: title={'center': 'SVK'}>, <Axes: title={'center': 'SVN'}>,
#         <Axes: title={'center': 'SWE'}>, <Axes: title={'center': 'SYC'}>,
#         <Axes: title={'center': 'SYR'}>, <Axes: title={'center': 'TGO'}>,
#         <Axes: title={'center': 'THA'}>, <Axes: title={'center': 'TJK'}>],
#        [<Axes: title={'center': 'TMP'}>, <Axes: title={'center': 'TUN'}>,
#         <Axes: title={'center': 'TUR'}>, <Axes: title={'center': 'TWN'}>,
#         <Axes: title={'center': 'TZA'}>, <Axes: title={'center': 'UGA'}>,
#         <Axes: title={'center': 'UKR'}>, <Axes: title={'center': 'UMI'}>,
#         <Axes: title={'center': 'URY'}>, <Axes: title={'center': 'USA'}>,
#         <Axes: title={'center': 'UZB'}>, <Axes: title={'center': 'VEN'}>],
#        [<Axes: title={'center': 'VGB'}>, <Axes: title={'center': 'VNM'}>,
#         <Axes: title={'center': 'ZAF'}>, <Axes: title={'center': 'ZMB'}>,
#         <Axes: title={'center': 'ZWE'}>, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
sns.pairplot(mydata)
